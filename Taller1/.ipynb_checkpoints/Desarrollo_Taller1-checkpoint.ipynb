# %% [markdown]
# # Taller 1. Análisis de la metodología para la verificación y construcción de series históricas para el cálculo de la ENFICC en plantas solares fotovoltaicas.

# %% [markdown]
# El presente archivo muestra los requerimientos del taller 1 desarrollados por iteral. En cada uno de los iterales desarrollados se presenta el análisis correspondiente, resultados y gráficas implementadas. De esta manera, el contenido del taller se divide de la siguiente manera:
#
# 1. Importación de datos y creación del DataFrame
# 2. Implementación de una función que permita graficar la distribución de energía y comparación entre diferentes series
# 3. Implementación de una función para el cálculo de la ENFICC
# 4. Implementación de una función para la metodología MCP basada en relación de varianzas
# 5. Implementación de una función para el cálculo de de los errores planteados: RMS, MBE y KSI (P-Value)

# %%
import os
import pandas as pd
import math as m
import numpy as np
import scipy as sp
from scipy import stats
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pwd
# Out:
# '/home/nbuser/library/Taller1'

# %% [markdown]
# ## 1. Importación de datos y creación del DataFrame
#
# Este primer punto presenta el código utilizado para la importación de los datos de la ciudad de Cali. En dicho código, la serie_pd_tierra representa el DataFrame de radiación del IDEAM en formato horario, y la serie_pd_satelite representa el DataFrame de los datos satelitales (NREL) también en dicho formato.

# %%
base_dir = os.path.join( '.','data')
ciudad = 'Cali'
fuente_tierra = 'IDEAM'
fuente_satelite = 'NREL'
serie_csv_tierra = os.path.join(base_dir,ciudad,fuente_tierra+'.csv')
serie_pd_tierra = pd.read_csv(serie_csv_tierra, sep = ';',
                encoding='latin-1')

serie_csv_satelite = os.path.join(base_dir,ciudad,fuente_satelite+'.csv')
serie_pd_satelite = pd.read_csv(serie_csv_satelite, sep = ';',
                encoding='latin-1')

# %% [markdown]
# ## 2. Implementación de una función que permita graficar la distribución de energía y comparación entre diferentes series

# %% [markdown]
# Luego de haber importado los datos, se procede a implementar una función que permita graficar la distribución de energía y comparación entre diferentes series. Lo primero es definir las funciones ghi_mensual y ghi_dia, las cuales retornan cada una un DataFrame (ghi_df) con los valores de la radiación promedio mensual y diaria, respectivamente.

# %%
def ghi_mensual(serie_horaria):
    agnos = sorted(serie_horaria['AÑO'].unique())
    ghi_df = pd.DataFrame(columns=["AÑO", "MES", "DIAS", "GHImes"])
    for agno in agnos:
        for mes in range(1,13):
            nombre_energia = list(serie_horaria)[-1]
            dias = sorted(serie_horaria[(serie_horaria['AÑO'] == agno) & (serie_horaria['MES'] == mes)]["DIA"].unique())
            ghi_mes = serie_horaria.loc[((serie_horaria["AÑO"] == agno) & (serie_horaria["MES"] == mes)), nombre_energia].sum()/1000
            ghi_dict = {"AÑO":agno, "MES":mes, "DIAS":dias[-1],
                        "GHImes":ghi_mes}
            ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
    return ghi_df

# %%
def ghi_dia(serie_ghi_mensual):
    agnos = sorted(serie_ghi_mensual['AÑO'].unique())
    ghi_df = pd.DataFrame(columns=["AÑO", "MES", "GHIdiario"])
    for agno in agnos:
        for mes in range(1,13):
            dias = serie_ghi_mensual.loc[((serie_ghi_mensual["AÑO"] == agno)
                            & (serie_ghi_mensual["MES"] == mes))
                                         ,"DIAS"].item()
            ghi_diario = serie_ghi_mensual.loc[(
                (serie_ghi_mensual["AÑO"] == agno)
                            & (serie_ghi_mensual["MES"] == mes)),
                "GHImes"].item()/dias
            ghi_dict = {"AÑO":agno, "MES":mes, "GHIdiario":ghi_diario}
            ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
    return ghi_df

# %% [markdown]
# Aplicando las funciones anteriores a los DataFrame correspondientes (serie_pd_tierra y serie_pd_satelital), se obtienen dos listas con los valores de la radiación ordenados de menor a mayor aplicando la función sorted(). De esta manera, la lista datos_IDEAM representa la lista del promedio mensual diario de la radiación de los datos en tierra, y la lista datos_NREL representa la lista del promedio mensual diario de la radiación de los datos del satélite.

# %%
# Aplicación de las funciones para los datos en la tierra
ghi_mensual_loc_tierra = ghi_mensual(serie_pd_tierra)
ghi_diario_loc_tierra = ghi_dia(ghi_mensual_loc_tierra)
datos_IDEAM = sorted(ghi_diario_loc_tierra["GHIdiario"]);

# Aplicación de las funciones para los datos satelitales

ghi_mensual_loc_satelite = ghi_mensual(serie_pd_satelite)
ghi_diario_loc_satelite = ghi_dia(ghi_mensual_loc_satelite)
datos_NREL = sorted(ghi_diario_loc_satelite["GHIdiario"])

# %% [markdown]
# Después de esto, se procede a definir la función para graficar ambas series de datos sobre la misma figura. La figura obtenida va a mostrar la distribución de la energía diaria promedio calculada a partir de la serie del IDEAM y la serie del NREL con resolución horaria. En la figura ambas series se encuentran normalizadas con respecto al valor mínimo de la serie de datos del IDEAM de acuerdo al documento del protocolo.

# %%
def graf(datos_id, datos_nr):

    pylab.xlabel("Datos")
    pylab.ylabel("Energía/Energía Base IDEAM")
    numdatos_tierra = range(len(datos_id))
    numdatos_satelite = range(len(datos_nr))
    pylab.plot(numdatos_tierra,datos_id/datos_id[0],'-k', label='IDEAM')
    pylab.plot(numdatos_satelite,datos_nr/datos_id[0],'--r', label='NREL')

    pylab.grid()
    pylab.legend(loc='upper left')
    
    pylab.title("Figura 1. Gráfica resultado al implementar la función $graf()$ para dos series de datos diferentes (IDEAM y NREL)")
    
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(15, 5)

# %% [markdown]
# Con esta función definida, se procede a aplicarla sobre las dos series de datos, las cuales son de diferente longitud. Así, se muestra la siguiente figura:

# %%
graf(datos_IDEAM, datos_NREL)

# %% [markdown]
# #### Análisis de gráfica:
#
# Al comparar la radiación del IDEAM con respecto a la del NREL se puede observar que:
#
# - Del dato 0 hasta el dato 103 (aproximadamente) la distancia entre las gráficas no varía demasiado e incluso disminuye, por lo cual se puede decir que la tendencia de las series es similiar, y se tiene un error entre las mismas que es prácticamente constante.
#
#
# - A partir del dato 103 hasta el final de la serie IDEAM los datos pierden su tendencia, de tal forma que la distancia entre ambas series cambia drásticamente hasta el punto en el cual  la serie NREL se intersecta con la del IDEAM. Esto significa que, en este segmento, los datos del IDEAM están sesgados y que la toma de datos contiene un error que hace que la radiación registrada aumente de manera desproporcionada en algunos meses. De esta manera, se esperaría que al aplicar el ajuste con la metodología MCP se presente un segmento anormal, en el cual la diferencia entre la radiación de ambas series vaya en aumento.

# %% [markdown]
# ## 3. Implementación de una función para el cálculo de la ENFICC

# %% [markdown]
# Luego esto, se procede a calcular el valor de la ENFICC(99%) con base en los datos obtenidos para las dos series de datos (IDEAM y NREL). Como se puede esperar, los valores de la ENFICC van a ser diferentes para las dos series, por lo cual se procederá a calcular la diferenciar porcentual de dichas valores para los análisis. Dicha diferencia porcentual se piensa reducir con el método del ajuste MCP, de tal forma que se calculará un nuevo valor de la diferencia de la ENFICC después de aplicar dicho ajuste en el iteral 4. Así, la función de la enficc es la siguiente:

# %%
def enficc(s_ideam, s_nrel):
    percentil = 0.01
    enficc_tierra = s_ideam.quantile(q=percentil, 
                                 numeric_only=True)["GHIdiario"]
    enficc_satelite = s_nrel.quantile(q=percentil, 
                                 numeric_only=True)["GHIdiario"]   
    print('La ENFICC 99% de la serie IDEAM es: ', "%.2f" % enficc_tierra)
    print('La ENFICC 99% de la serie NREL es: ', "%.2f" % enficc_satelite)
    dp = ((enficc_satelite- enficc_tierra)/enficc_tierra)*100
    print('La diferencia porcentual de las ENFICC es [%]: ', "%.2f" % dp)

# %% [markdown]
# Luego, se procede a aplicar dicha función. En este caso, se espera que los dos valores de la ENFICC sean muy diferentes, ya que, como se explico anteriormente, los datos no han sido ajustados por el método MCP. Dicho esto, los resultados para la ENFICC en las dos series son los siguientes:

# %%
enficc(ghi_diario_loc_tierra, ghi_diario_loc_satelite)
# Out:
# La ENFICC 99% de la serie IDEAM es:  3.33
# La ENFICC 99% de la serie NREL es:  4.36
# La diferencia porcentual de las ENFICC es [%]:  30.93

# %% [markdown]
# Calculando la diferencia porcentual entre estos (la cual se define en este caso como: $DP[\%] = (enficc_i - enficc_n)/(enficc_n)*100 $) se puede apreciar que la serie NREL sobreestima los datos de la radiación del IDEAM en un 30.92$\%$. Este valor se analizará nuevamente luego del ajuste MCP.

# %% [markdown]
# ## 4. Implementación de una función para la metodología MCP basada en relación de varianzas

# %% [markdown]
# Como bien se sabe, la metodología MCP se aplica a partir de un número de meses determinado. Esto significa que es necesario seccionar la serie para que se obtenda un DataFrame desde un mes inicial hasta un mes final. De esta forma, se define la función serie_corta, la cual tiene como entradas el DataFrame a seccionar, el año en el cual se eligen los meses para el ajuste, el mes inicial y el mes final. Luego de aplicar la función, esta retorna un nuevo DataFrame (ghi_df) con la serie corta.

# %%
def serie_corta(serie_h_tierra, agno, mes_inicio, mes_final):
    corta=[]
    for mes in range(mes_inicio,mes_final+1):
        datos=serie_h_tierra.loc[(serie_h_tierra["AÑO"] == agno)& (serie_h_tierra["MES"] == mes)]
        corta.append(datos)
        ghi_df = pd.concat(corta)
            
    return ghi_df

# %% [markdown]
# Debido a que se desea realizar varios ajustes con diferentes rangos de meses en algunos años, esta función se va a aplicar más de una vez. En total se aplicó la función 6 veces, en el cual se realizó el ajuste del error en los años 2009 y 2013 para los siguientes rangos de meses: 1 a 3 meses, 1 a 6 meses, y 1 a 12 meses.

# %%
# AJUSTES PARA EL AÑO 2009
serie_corta_1 = serie_corta(serie_pd_tierra, 2009, 1, 3)
serie_corta_2 = serie_corta(serie_pd_tierra, 2009, 1, 6)
serie_corta_3 = serie_corta(serie_pd_tierra, 2009, 1, 12)
# AJUSTES PARA EL AÑO 2013
serie_corta_4 = serie_corta(serie_pd_tierra, 2013, 1, 3)
serie_corta_5 = serie_corta(serie_pd_tierra, 2013, 1, 6)
serie_corta_6 = serie_corta(serie_pd_tierra, 2013, 1, 12)

# %% [markdown]
# Con esta función definida, se procede a hacer la función del método de ajuste MCP, cuyas entradas son: la serie seccionada en formato horario, y la serie satelital en este mismo formato. En este caso, la salida es un DataFrame de nombre no_negativos que devuelve la serie satelital ajustada. Esta función también elimina los valores negativos de la radiación ya que el ajuste MCP genera valores menores a cero para aquellos datos que no registran radiación alguna (datos tomados en la noche).

# %%
def mcp(serie_tierra_c, serie_satelital):
    
    satelital_corta = []
    agno = int(serie_tierra_c['AÑO'][0:1])
    mes_inicio = int(serie_tierra_c['MES'][0:1])
    mes_final = int(serie_tierra_c['MES'][-2:-1]) 
    ghi_df = serie_corta(serie_satelital, agno, mes_inicio, mes_final)
    satelital_modificada = serie_satelital.copy(deep=True)
    
    media_tierra = serie_tierra_c['IDEAM'].mean()
    desv_tierra = np.std(serie_tierra_c['IDEAM'])

    media_satelite = ghi_df['NREL'].mean()
    desv_satelite = np.std(ghi_df['NREL'])
    m = (desv_tierra/desv_satelite)
    satelital_modificada['NREL'] = (media_tierra - m*media_satelite) + m*(serie_satelital['NREL'])
    
    offset = float(satelital_modificada['NREL'][0:1]) 
    no_negativos = satelital_modificada.replace(offset,0)
           
    return no_negativos

# %% [markdown]
# Con la función realizada, se procede a aplicar el ajuste mcp a los datos satelites con las 15 series de datos mencionadas anteriormente. De esta manera, se definen los DataFrame con nombre mcp, los cuales tienen la radiación satelital ajustada de los 10 años en formato horario.

# %%
# AJUSTES PARA EL AÑO 2009
mcp_1 = mcp(serie_corta_1, serie_pd_satelite);mcp_2 = mcp(serie_corta_2, serie_pd_satelite);mcp_3 = mcp(serie_corta_3, serie_pd_satelite)
# AJUSTES PARA EL AÑO 2013
mcp_4 = mcp(serie_corta_4, serie_pd_satelite);mcp_5 = mcp(serie_corta_5, serie_pd_satelite);mcp_6 = mcp(serie_corta_6, serie_pd_satelite)

# %% [markdown]
# Con estas series definidas, se procede a realizar 2 figuras (una por año) para mirar como los ajustes mensuales realizados afectan la diferencia porcentual de la ENFICC. En cada una de las figuras se grafican 3 series de rango de meses (1-3 meses, 1-6 meses, 1-12 meses). Con base en esto, se entrega la que mejor se ajusta a la IDEAM (menor diferencia porcentual de la ENFICC). Para facilitar el proceso, se definio una sola función que tiene como entrada 7 DataFrames (6 series NREL ajustadas y una serie del IDEAM) y como sálida tiene 2 gráficas.

# %%
def graf_multiple(datos_id, serie_1, serie_2, serie_3, serie_4, serie_5, serie_6):      
    
    dataFrame_colection = {}
    mensual_ajustada_1 = ghi_mensual(serie_1);diaria_ajustada_1 = ghi_dia(mensual_ajustada_1);ajuste_1 = sorted(diaria_ajustada_1["GHIdiario"]);dataFrame_colection[1] = diaria_ajustada_1 
    mensual_ajustada_2 = ghi_mensual(serie_2);diaria_ajustada_2 = ghi_dia(mensual_ajustada_2);ajuste_2 = sorted(diaria_ajustada_2["GHIdiario"]);dataFrame_colection[2] = diaria_ajustada_2
    mensual_ajustada_3 = ghi_mensual(serie_3);diaria_ajustada_3 = ghi_dia(mensual_ajustada_3);ajuste_3 = sorted(diaria_ajustada_3["GHIdiario"]);dataFrame_colection[3] = diaria_ajustada_3
    mensual_ajustada_4 = ghi_mensual(serie_4);diaria_ajustada_4 = ghi_dia(mensual_ajustada_4);ajuste_4 = sorted(diaria_ajustada_4["GHIdiario"]);dataFrame_colection[4] = diaria_ajustada_4
    mensual_ajustada_5 = ghi_mensual(serie_5);diaria_ajustada_5 = ghi_dia(mensual_ajustada_5);ajuste_5 = sorted(diaria_ajustada_5["GHIdiario"]);dataFrame_colection[5] = diaria_ajustada_5
    mensual_ajustada_6 = ghi_mensual(serie_6);diaria_ajustada_6 = ghi_dia(mensual_ajustada_6);ajuste_6 = sorted(diaria_ajustada_6["GHIdiario"]);dataFrame_colection[6] = diaria_ajustada_6
    numdatos_tierra = range(len(datos_id))
    num_datos_3_meses = range(len(ajuste_1)) 
    num_datos_6_meses = range(len(ajuste_2)) 
    num_datos_9_meses = range(len(ajuste_3)) 
    
    fig, axes = plt.subplots(1, 2, figsize=(15,6))
    axes[0].plot(numdatos_tierra, datos_id/datos_id[0], '-k', label='IDEAM')
    axes[0].plot(num_datos_3_meses, ajuste_1/datos_id[0], '-g', label='NREL - ajuste 3 meses')
    axes[0].plot(num_datos_6_meses, ajuste_2/datos_id[0], '--r', label='NREL - ajuste 6 meses')
    axes[0].plot(num_datos_9_meses, ajuste_3/datos_id[0], '--b', label='NREL - ajuste 12 meses')
    axes[0].set_title("Figura 2. Ajuste MCP realizado con segmentos del año 2009")
    axes[0].set_xlabel("Datos")
    axes[0].set_ylabel("Energía/Energía Base IDEAM")
    axes[0].grid()
    axes[0].legend(loc='upper left')
    axes[1].plot(numdatos_tierra, datos_id/datos_id[0], '-k', label='IDEAM')
    axes[1].plot(num_datos_3_meses, ajuste_4/datos_id[0], '-g', label='NREL - ajuste 3 meses')
    axes[1].plot(num_datos_6_meses, ajuste_5/datos_id[0], '--r', label='NREL - ajuste 6 meses')
    axes[1].plot(num_datos_9_meses, ajuste_6/datos_id[0], '--b', label='NREL - ajuste 12 meses')
    axes[1].set_title("Figura 3. Ajuste MCP realizado con segmentos del año 2013")
    axes[1].set_xlabel("Datos")
    axes[1].set_ylabel("Energía/Energía Base IDEAM")
    axes[1].grid()
    axes[1].legend(loc='upper left')
    
    enficcs = []
    dp = []
    percent = 0.01
    enficc_tierra = ghi_diario_loc_tierra.quantile(q=percent, 
                                 numeric_only=True)["GHIdiario"]
    for i in range(1,7):   
        enficcs.append(dataFrame_colection[i].quantile(q=percent, 
                                 numeric_only=True)["GHIdiario"])
        dp.append((abs((enficcs[i-1] - enficc_tierra))/enficc_tierra)*100)
        
    print(f'La diferencia porcentual de la ENFICC del año 2009 para el ajuste de 3 meses es [%]: ', "%.2f" % dp[0])
    print(f'La diferencia porcentual de la ENFICC del año 2009 para el ajuste de 6 meses es [%]: ', "%.2f" % dp[1])
    print(f'La diferencia porcentual de la ENFICC del año 2009 para el ajuste de 12 meses es [%]: ', "%.2f" % dp[2])
    print(f'La diferencia porcentual de la ENFICC del año 2013 para el ajuste de 3 meses es [%]: ', "%.2f" % dp[3])
    print(f'La diferencia porcentual de la ENFICC del año 2013 para el ajuste de 6 meses es [%]: ', "%.2f" % dp[4])
    print(f'La diferencia porcentual de la ENFICC del año 2013 para el ajuste de 12 meses es [%]: ', "%.2f" % dp[5])

# %% [markdown]
# Con base en lo anterior, al aplicar la función graf_multiple se obtienen las siguientes dos gráficas. En estas se puede apreciar como el ajuste cambia con el numero de meses y el año utilizado. Adicional a esto, se muetran las diferencias porcentuales de las ENFICC para los 2 años.

# %%
graf_multiple(datos_IDEAM, mcp_1, mcp_2, mcp_3, mcp_4, mcp_5, mcp_6)
# Out:
# La diferencia porcentual de la ENFICC del año 2009 para el ajuste de 3 meses es [%]:  11.10
# La diferencia porcentual de la ENFICC del año 2009 para el ajuste de 6 meses es [%]:  12.09
# La diferencia porcentual de la ENFICC del año 2009 para el ajuste de 12 meses es [%]:  11.93
# La diferencia porcentual de la ENFICC del año 2013 para el ajuste de 3 meses es [%]:  1.74
# La diferencia porcentual de la ENFICC del año 2013 para el ajuste de 6 meses es [%]:  5.10
# La diferencia porcentual de la ENFICC del año 2013 para el ajuste de 12 meses es [%]:  9.02

# %% [markdown]
# #### Análisis de las ENFICC y las gráficas:
#
# Al analizar los resultados obtenidos se puede decir lo siguiente:
#
# - Al aplicar el método MCP, los valores de las diferencias porcentuales de las ENFICC disminuyeron en comparación con el valor inicial de 30.92%, por lo cual se logró ajustar los datos y aproximarlos de una manera aceptable.
#
# - Se puede decir hay bastante variación respecto a las diferencias de ENFICC en los ajustes mensuales en el 2009 y 2013. En otras palabras, si se compara el ajuste de 3 meses en los 2 años, el ajuste de 6 meses en los 2 años, y el ajuste de 12 meses en los 2 años, se encuentra que son valores muy diferentes. Así, se observa que, en general, las diferencias porcentuales del año 2013 son menores a las del 2009, por lo cual se puede decir que el 2013 es un mejor año para realizar el ajuste (en términos de la ENFICC99%).
#
# - Con respecto al valor de la diferencia porcentual de la ENFICC, se puede decir que la serie de datos que proporcionó el mejor ajuste fue la serie de 12 meses de rango del año 2013.

# %% [markdown]
# Finalmente, se procede a calcular los errores de RMSEn, MBE KSI(p-value) para cada uno de los ajustes realizados

# %% [markdown]
# ## 5. Implementación de una función para el cálculo de de los errores planteados: RMS, MBE y KSI (P-Value)

# %% [markdown]
# Finalmente, el último paso consiste en calcular los errores  RMS, MBE y KSI (PValue). Con estos errores es posible evaluar la precisión del ajuste realizado en el iteral anterior. Así, se definió la función -errores-, la cual tiene como entrada 2 dataFrame (datos de la IDEAM y datos NREL corregidos) y como salida 1 lista que devuelve los errores calculados. En dicha, los errores se ordenan de la siguiente manera: errores[0] = RMS, errores[1] = MBE y errores[2] = KSI (PValue).

# %%
def errores(ideam,corregida):
    corregida_corta = []
    agno = int(ideam['AÑO'][0:1])
    mes_inicio = int(ideam['MES'][0:1])
    mes_final = int(ideam['MES'][-2:-1]) 
    for mes in range(mes_inicio,(mes_final+1)):
        datos_c = corregida.loc[(corregida["AÑO"] == agno)& (corregida["MES"] == mes)]
        corregida_corta.append(datos_c)
        dfc = pd.concat(corregida_corta) 
    a = list(ideam['IDEAM'])
    b = list(dfc['NREL'])
    datos_id = pd.DataFrame(a)
    datos_nrel = pd.DataFrame(b)
    rmsen = ((m.sqrt(((datos_id[0]-datos_nrel[0])**2).mean()))/(max(datos_id[0])-min(datos_nrel[0])))*100
    MBE = abs((((datos_nrel[0] - datos_id[0]).mean())*len(datos_id[0])/(datos_id[0].mean()*len(datos_id[0]))))*100
    pi_value = stats.ks_2samp(datos_id[0],datos_nrel[0])
    errores = [rmsen, MBE, pi_value[1]*100]
    return errores

# %%
# EVOLUCIÓN DE ERRORRES PARA EL AÑO 2011
eh_1 = errores(serie_corta_1, mcp_1);eh_2 = errores(serie_corta_2, mcp_2);eh_3 = errores(serie_corta_3, mcp_3)
# EVOLUCIÓN DE ERRORRES PARA EL AÑO 2012
eh_4 = errores(serie_corta_4, mcp_4);eh_5 = errores(serie_corta_5, mcp_5);eh_6 = errores(serie_corta_6, mcp_6)

# %% [markdown]
# Luego de haber aplicado la función y organizarlos en diferentes listas (eh), los errores se reportan en la siguiente tabla:

# %%
data = {'KSI(PValue)': ["%.6f" %eh_1[2],"%.6f" % eh_2[2],"%.6f" % eh_3[2],"%.6f" % eh_4[2],"%.6f" % eh_5[2],"%.6f" % eh_6[2]], 
        'Año': [2011, 2011, 2011, 2012, 2012, 2012], 
        'Error RMSEn [%]': ["%.2f" % eh_1[0], "%.2f" % eh_2[0], "%.2f" % eh_3[0], "%.2f" % eh_4[0], "%.2f" % eh_5[0], "%.2f" % eh_6[0]],
        'Error MBE [%]': ["%.2f" %eh_1[1], "%.2f" % eh_2[1], "%.2f" % eh_3[1], "%.2f" % eh_4[1], "%.2f" % eh_5[1], "%.2f" %  eh_6[1]]}
df = pd.DataFrame(data, index = ['Ajuste con 3 meses', 'Ajuste con 6 meses', 'Ajuste con 12 meses', 'Ajuste con 3 meses',
                                 'Ajuste con 6 meses', 'Ajuste con 12 meses'])
df
# Out:
#                       Año Error MBE [%] Error RMSEn [%] KSI(PValue)
# Ajuste con 3 meses   2011          1.13           11.14    0.040655
# Ajuste con 6 meses   2011          1.59           10.62    0.000046
# Ajuste con 12 meses  2011          1.21           11.02    0.000000
# Ajuste con 3 meses   2012          0.72           13.71    5.398651
# Ajuste con 6 meses   2012          1.25           12.75    3.769841
# Ajuste con 12 meses  2012          1.08           12.55    0.103388

# %% [markdown]
# Para interpretar mejor los resultados, se realizaron 3 gráficas en total (1 por error), en las cuales se compara la evolución de los errores con respecto a los meses en cada uno de los años. Dicho esto, las gráficas son las siguientes:

# %%
# GRÁFICA DEL ERROR RMSEn
pylab.xlabel("Ajuste por meses")
pylab.ylabel("Error RMSEn [%]")
meses = [3,6,12]
errores_RMSEn_1 = [eh_1[0], eh_2[0], eh_3[0]]
errores_RMSEn_2 = [eh_4[0], eh_5[0], eh_6[0]]
pylab.grid()
pylab.plot(meses, errores_RMSEn_1, '--og', label='Ajuste para el año 2009' )
pylab.plot(meses, errores_RMSEn_2, '--ob', label='Ajuste para el año 2013' )
pylab.legend(loc='upper left')
pylab.title("Figura 4. Evolución del error RMSEn con respecto al número de meses")
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 5)

# %%
# Gráfica del Error MBE
pylab.xlabel("Ajuste por meses")
pylab.ylabel("Error MBE [%]")
meses = [3,6,12]
errores_RMSEn_1 = [eh_1[1], eh_2[1], eh_3[1]]
errores_RMSEn_2 = [eh_4[1], eh_5[1], eh_6[1]]
pylab.grid()
pylab.plot(meses, errores_RMSEn_1, '--om', label='Ajuste para el año 2009' )
pylab.plot(meses, errores_RMSEn_2, '--oy', label='Ajuste para el año 2013' )
pylab.legend(loc='upper left')
pylab.title("Figura 5. Evolución del error MBE con respecto al número de meses")
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 5)

# %%
# Gráfica del error KSI (PValue)
pylab.xlabel("Ajuste por meses")
pylab.ylabel("Error KSI (PValue))")
meses = [3,6,12]
errores_RMSEn_1 = [eh_1[2], eh_2[2], eh_3[2]]
errores_RMSEn_2 = [eh_4[2], eh_5[2], eh_6[2]]
pylab.grid()
pylab.plot(meses, errores_RMSEn_1, '--ok', label='Ajuste para el año 2011' )
pylab.plot(meses, errores_RMSEn_2, '--or', label='Ajuste para el año 2012' )
pylab.legend(loc='upper left')
pylab.title("Figura 6. Evolución del error KSI(PValue) con respecto al número de meses")
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 5)

# %% [markdown]
# #### Análisis de los errores obtenidos:
#
# A partir de la tabla de errores obtenida, y de las figuras 4, 5 y 6, es posible decir lo siguiente:
#
#
# - Para los años analizados, el ajuste que más reduce los errores es el de 12 meses, lo cual ocurre tanto en el año 2009 como en el 2013. Estas funciones también fueron aplicadas para el año 2011 y 2012, con los cuales se obtuvo el mismo resultado: el ajuste con el mayor número de meses (en 1 año) reduce los errores obtenidos, y por lo tanto corrige mejor los datos obtenidos del satélite con respecto a los datos obtenidos en tierra. Este resultado se repite para todos los errores (RMSEn, MBS y KSI)
#
# - Siendo el ajuste de 12 meses el que más reduce el error, se podría plantear que la curva de la radiación de este ajsute debe ser la más cercana a los datos del IDEAM. Esta afirmación se puede verificar al analizar las figuras 2 y 3, las cuales muestran que la curva que presenta menor distancia entre los datos es la de 12 meses.
#
# - A pesar de que este el ajuste de 12 meses es el que más reduce el error, es posible observar que no es el de la menor diferencia porcentual de ENFICC99%. el ajuste que tiene el menor valor para esta diferencia es la de 3 meses.
